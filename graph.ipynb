# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np

# %%
def func(x, a, b):
    return a / x + b

# %%
data = {
    1: 13665.4,
    2: 6898.799999999999,
    3: 4576.2,
    4: 3398.4,
    5: 2741.7999999999997,
    6: 2293.2,
    7: 1945.4,
    8: 1729.9999999999998,
    9: 1532.2000000000003,
    10: 1381.8
}

popt, pcov = curve_fit(func, list(data.keys()), list(data.values()))

a, b = popt
print(a, b)


plt.scatter(data.keys(), data.values())
# Out:
# 13671.7993302756 11.893369312270938
